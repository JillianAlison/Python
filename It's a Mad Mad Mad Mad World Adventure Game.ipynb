# %%
# The following Adventure Game is based on the film 'It's a Mad Mad Mad Mad World'.

"""
DocString:
The following Adventure Game is based on the 1963 American comedy film 
It's a Mad Mad Mad Mad World. The game consits of 4 stages complete them 
within 3 minutes to find the barried treasure under the big W!

Bugs: None known at this time.
"""

# Importing nessisary functions 
from sys import exit
import time
import random

# User-defined fail function for when the player loses the game
def fail():
    print("""You lose!\n
    Captain Cold Pepper tracked you down.""")
    input()
    exit()
# Define time limit variables to time the game, users have 3 minutes.
time_limit = 180
stage = 1

# Introduction
# User-defined introduction 'start' that introduces the game and starts the timer.
def start():
    print("""
    The year is 1963, you are driving on California State Route 74. 
    When all of the sudden you are passed by a reckless driver. As he 
    continues racing around blind corners he "goes flyin right out there" 
    and drives his car off the road and down into a ditch.
    """)
    input("*Press enter to continue*\n")
    flyin_right_out_there()
start_time = time.time()
    
# Stage 1   
# User-defined introduction 'stage 1' users have 3 options to choose from
def flyin_right_out_there():
    print("""
    After witnessing this accident what would you like to do?
    1.) Go down to the accident and see if he is okay
    2.) Stop your car and look over the edge
    3.) Continue driving, there is no way anyone survived that fall
    """)
    
# User Input as well as input handling by converting thier input to lowercase 
    answer = input("  \n").lower()
    
# Conditional and Nested Conditional Statements (if/elif/else)
# Users are able to put in a key word or number to select an option 
# Based on their selection they move to the next stage, repeat or end.
    if "1" in answer or "go down" in answer or "see if he is okay" in answer:
        print("\nYou're such a good person!\n")
        input("<Press enter to continue>\n")
        road()
    
    elif "2" in answer or "stop" in answer or "look over the edge" in answer:
        print("""\nNow that you've seen the crash, what would you like to do?.""")
        input("<Press enter to continue>\n")
        flyin_right_out_there()
    
    elif "3" in answer or "run" in answer:
        print("\nWell I hope you'd at least call 9-11!")
        print("See ya")
    
    else:
        print("I'm not sure what you want to do... Try 1, 2, or 3")
        input("<Press enter to continue>\n")
        flyin_right_out_there()
        
# Stage 2
# Guessing game where user has 3 chnaces to guess the correct number of shares
def wrong():
    print("You ran out of chances")
    
# The correct answer is 3
def road():
  shares = 3
  my_shares = 3
    
# Loops (for/while)
  for share in range(shares):
        
# Controlling for Errors (try/except)
# If users correctly guess 3 before running out of chances they move on
    try:
      guess = int(input(""" \n
    You and 5 men go down to the scene of the accident. You discover an old 
    man who on his death bed shares he has barried $350,000 under a big 'W'. 
    After he kicks the bucket two police offers join and question you. No one 
    reveals anthing about the big 'W'. Everyone gets back into thier cars and 
    tells the rest of thier party what happened. You continue driving before 
    pulling over to make a plan. You have to agree on how to divide the money.\n
    1 share for going down to the crash
    1 share for having a vehicle 
    1 share for being a person in the vehicle\n 
    How many shares should you get?\n
    Select a number 1-5:
    """))
      if guess < 1 or guess > 5:
        raise ValueError("Invalid input: number must be between 1 and 5")
      correct_answer = 3
      if guess == correct_answer:
        print("\nExactly, Thats fair!\n")
        input("<Press enter to continue>\n")
        Old_fashioneds()
        break
      else:
        print("\nNo way! Thats not fair!\n")
        input("<Press enter to continue>\n")
        
# Controlling for Errors (try/except)
    except ValueError as error:
      print(error)
      shares += 1
    if shares != my_shares:
        wrong()

# Stage 3
# Users are able to put in a key word or number to select an option 
# Based on their selection they move to the next stage, repeat or end.
def Old_fashioneds():
    print(""" \
    After racing back to your car you head stright to the nearest airport.
    Where you discover there are a few grim options:
    1.) Charter a rickety old plane
    2.) Have Mr. Fitzgerald take you in his private plane
    3.) Continue driving 
    """)
                
# User Input as well as input handling by converting thier input to lowercase         
    pick = input("  \n").lower()
    
# Conditional and Nested Conditional Statements (if/elif/else)
    if "1" in pick or "charter" in pick or "old plane" in pick:
        print("""\n
        Your rickety old plane landed you first in Santa Rosita but you
        end up accidently locking yourself in a hardwarestore.\n""")
        input("<Press enter to continue>\n""")
        fail()
    
    elif "2" in pick or "mr. fitzgerald" in pick or "private plane" in pick:
        print("""\n
        Mr. Fitzgerald had a few too many old fashioneds and passed out. 
        You ended up having to land the plane yourself.\n""")
        input("<Press enter to continue>\n""")
        fail()
    
    elif "3" in pick or "driving " in pick or "continue " in pick:
        print("""\n
        Good choice, you continue down the road until...\n""")
        input("<Press enter to continue>\n""")
        Sylvestor()
    
    else:
        print("I'm not sure what you want to do... Try 1, 2, or 3")
        input("<Press enter to continue>\n")
        Old_fashioneds()
    
# Stage 4
# Users are able to put thier fate up to chance by getting a random option  
def Sylvestor():
    print(""" \
    Your car breaks down!\n
    You have a varity of options, you start to walk down the highway and leave
    your fate up to chance.
    """)

    option_list = ['You find a little girls bike and ride it to the nearest\
gas station', 
    'You find a pay phone and call Sylvestor in Rosita beach to get the money',
    'You Hitch Hike and an Australian Botonist picks you up',
    'You Hitch Hike and a nice gentlemen picks you up',
    'You Hitch Hike and a mean man picks you up']
    
    options = 2
#while loop that randomizes 5 options and allows the user to put their fate up
# to chance
#The only option that wins is the Austrailian botonist 
    while options > 0:
        option = random.choice(option_list)
        input("<Press enter to see what fate has in store for you!>\n")
        print(option)

        if option == option_list[0]:
            input("<Press enter to continue>\n")
            print("""\n
            Once you get to the gas station you find the man who double crossed 
            you. Your proceed to beat him up and tear down the new station.\n""")
            options -=1
            input("<Press enter to continue>\n")
            fail()

        elif option == option_list[1]:
            input("<Press enter to continue>\n")
            print("""\n
            Unfortunately Sylvestor didnt listen to you and instead of going to 
            get the money he is 'comin ta get ya mama!'\n""")
            options -=1
            input("<Press enter to continue>\n")
            fail()

        elif option == option_list[2]:
            input("<Press enter to continue>\n")
            print("""\n
         Good choice, the Australian Botonist takes you to Rosita Beach.\n""")
            options -=1
            input("<Press enter to continue>\n")
            big_W()

        elif option == option_list[3]:
            input("<Press enter to continue>\n")
            print("""\n
            But you trick him into Believing you work for the CIA you tell 
            him to go into a cafe to call them and you steal his car and 
            drive away.\n""")
            options -=1
            input("<Press enter to continue>\n")
            fail()

        elif option == option_list[4]:
            input("<Press enter to continue>\n")
            print("""\n
            After you tell him about the big 'W' he tells you to get out and 
            move debris from the road 'so no one trips over it in the dark' 
            while you are clearing the road he drives off and leaves you.\n""")
            options -=1
            input("<Press enter to continue>\n")
            fail()

# Ending of the game if users select the correct choice 
def big_W():
    print("""
    Congratulations!\n
    You got to Santa Rosita first and found the plam tree big 'w' you dig up a 
    box full of cash.\n""")
    input()
    exit()
    
# Time constratin picking the winner     
    end_time = time.time() - start_time
    if time.time() - time_start >= time_limit:
        print("You ran out of time, it took you", int(end_time), "seconds.")
        fail()
    elif end_time <= time_limit:
        print("You have won the game in", int(end_time), "seconds.")
    else:
        fail()        
    
start()
# Out:
#     The year is 1963, you are driving on California State Route 74.
#     When all of the sudden you are passed by a reckless driver. As he
#     continues racing around blind corners he "goes flyin right out there"
#     and drives his car off the road and down into a ditch.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jk/ykpv2ggj6fbd0f8c1d9sx0jw0000gn/T/ipykernel_1230/1091299089.py in <module>
#     252         fail()
#     253
# --> 254 start()
#
# /var/folders/jk/ykpv2ggj6fbd0f8c1d9sx0jw0000gn/T/ipykernel_1230/1091299089.py in start()
#      34     and drives his car off the road and down into a ditch.
#      35     """)
# ---> 36     input("*Press enter to continue*\n")
#      37     flyin_right_out_there()
#      38 start_time = time.time()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
